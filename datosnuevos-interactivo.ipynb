# %%
import pandas as pd
import numpy as np
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display
from ipywidgets.embed import embed_minimal_html

# %%
a = widgets.FloatText()
display(a)
# Out:
# FloatText(value=0.0)

# %%
b = widgets.FloatSlider()
a
# Out:
# FloatText(value=8.0)

# %% [raw]
# display(a,b)
#
# mylink = widgets.jslink((a, 'value'), (b, 'value'))

# %%
btn = widgets.Button(description='Lucas Pecina')
display(btn)
def btn_eventhandler(obj):
    print('Hello from the {} button!'.format(obj.description))
btn.on_click(btn_eventhandler)
# Out:
# Button(description='Lucas Pecina', style=ButtonStyle())

# %% [markdown]
# https://towardsdatascience.com/bring-your-jupyter-notebook-to-life-with-interactive-widgets-bc12e03f0916

# %%
presos_individual = pd.read_excel('/Users/lucaspecina/Desktop/Data/Work/PE/presos/NUEVOSDATOS/datos_nuevo_indiv.xlsx')
presos_individual.head()
# Out:
#    id_unico      f_nac f_ingreso_spb destino  años  meses  dias        rige  \
# 0     34317 1982-11-17    2008-06-04    U.17  25.0    0.0   0.0  05/02/2008
# 1     42052 1980-06-23    2012-05-03    U.17   NaN    NaN   NaN         NaN
# 2     81619 1959-03-08    2015-11-20    U.46   NaN    NaN   NaN         NaN
# 3    110002 1973-04-12    2018-02-05    U.30  18.0    0.0   0.0         NaN
# 4    110008 1996-01-07    2018-02-05    U.30  11.0    0.0   0.0         NaN
#
#        vence                             depto_judicial  ...  \
# 0        NaT       TRIBUNAL EN LO CRIMINAL N° 4-QUILMES  ...
# 1        NaT  JUZGADO DE GARANTIAS N° 3-TRENQUE LAUQUEN  ...
# 2        NaT      TRIBUNAL EN LO CRIMINAL N° 4-MERCEDES  ...
# 3 2034-12-02       JUZGADO DE GARANTIAS N° 3-LA MATANZA  ...
# 4 2027-12-02       JUZGADO DE GARANTIAS N° 3-LA MATANZA  ...
#
#         bj_protegido puede_salir media_delito_estandar tiene_vence  edad  \
# ...

# %%
presos_individual['tiempo_condena_año_int'] = presos_individual['tiempo_condena_año'].apply(lambda x: int(x) if pd.notnull(x) else x)
